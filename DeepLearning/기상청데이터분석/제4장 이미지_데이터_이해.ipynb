# %% [markdown]
# ### 4.1 파일 경로와 목록

# %%
#드라이브 마운트
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
img_path = '/content/drive/MyDrive/2022 DataCreatorCamp_나 is NICE/대학부 데이터셋'
img_path
# Out:
# '/content/drive/MyDrive/2022 DataCreatorCamp_나 is NICE/대학부 데이터셋'

# %% [markdown]
# #### 4.1.1 os.walk

# %%
import os

for dirpath, dirnames, filenames in os.walk(f'{img_path}'):
  print(dirpath, dirnames)
# Out:
# /content/drive/MyDrive/2022 DataCreatorCamp_나 is NICE/대학부 데이터셋 ['L2_39', 'L2_12', 'L2_41', 'L2_52', 'L2_30', 'L2_24', 'L2_3', 'L2_46', 'L2_15', 'L2_40', 'L2_34', 'L2_27', 'L2_25', 'L2_50', 'L2_45', 'L2_33', 'L2_44', 'L2_20', 'L2_10', 'L2_21']
# /content/drive/MyDrive/2022 DataCreatorCamp_나 is NICE/대학부 데이터셋/L2_39 []
# /content/drive/MyDrive/2022 DataCreatorCamp_나 is NICE/대학부 데이터셋/L2_12 []
# /content/drive/MyDrive/2022 DataCreatorCamp_나 is NICE/대학부 데이터셋/L2_41 []
# /content/drive/MyDrive/2022 DataCreatorCamp_나 is NICE/대학부 데이터셋/L2_52 []
# /content/drive/MyDrive/2022 DataCreatorCamp_나 is NICE/대학부 데이터셋/L2_30 []
# /content/drive/MyDrive/2022 DataCreatorCamp_나 is NICE/대학부 데이터셋/L2_24 []
# /content/drive/MyDrive/2022 DataCreatorCamp_나 is NICE/대학부 데이터셋/L2_3 []
# /content/drive/MyDrive/2022 DataCreatorCamp_나 is NICE/대학부 데이터셋/L2_46 []
# ...

# %% [markdown]
# #### 4.1.2 glob

# %%
import glob
img_paths_png = glob.glob(f'{img_path}/*/*.png') #png 확장자 가진 모든 파일 출력
img_paths_png
# Out:
# ['/content/drive/MyDrive/2022 DataCreatorCamp_나 is NICE/대학부 데이터셋/L2_39/clmmvtdeyrgypiajuxxt.png',
#  '/content/drive/MyDrive/2022 DataCreatorCamp_나 is NICE/대학부 데이터셋/L2_39/cgrmxpeqdvlqegsbdqcu.png',
#  '/content/drive/MyDrive/2022 DataCreatorCamp_나 is NICE/대학부 데이터셋/L2_39/iqgztfqaauycmlutynur.png',
#  '/content/drive/MyDrive/2022 DataCreatorCamp_나 is NICE/대학부 데이터셋/L2_39/vwgrbyrgxxllkcmhnrtd.png',
#  '/content/drive/MyDrive/2022 DataCreatorCamp_나 is NICE/대학부 데이터셋/L2_39/xbsrnxfptjsekxkfdbnx.png',
#  '/content/drive/MyDrive/2022 DataCreatorCamp_나 is NICE/대학부 데이터셋/L2_39/npjcwvthckysaggpmuud.png',
#  '/content/drive/MyDrive/2022 DataCreatorCamp_나 is NICE/대학부 데이터셋/L2_39/zzteeffveomlrzziyity.png',
#  '/content/drive/MyDrive/2022 DataCreatorCamp_나 is NICE/대학부 데이터셋/L2_39/aczmozevhplmbvgswbzl.png',
#  '/content/drive/MyDrive/2022 DataCreatorCamp_나 is NICE/대학부 데이터셋/L2_39/yoipmgkalgrrevdymwnr.png',
# ...

# %%
print(len(img_paths_png))
# Out:
# 1515

# %%
img_files_png=[]
for filename in img_paths_png:
  img_files_png.append(filename)

# %%
img_files_png[0]
# Out:
# '/content/drive/MyDrive/2022 DataCreatorCamp_나 is NICE/대학부 데이터셋/L2_39/clmmvtdeyrgypiajuxxt.png'

# %%
import glob
img_paths_jpg = glob.glob(f'{img_path}/*/*.jpg') #jpg 확장자 가진 모든 파일 출력

img_files_jpg=[]
for filename in img_paths_jpg:
  img_files_jpg.append(filename)
print(len(img_files_jpg))
# Out:
# 24195

# %%
img_files_jpg[0]
# Out:
# '/content/drive/MyDrive/2022 DataCreatorCamp_나 is NICE/대학부 데이터셋/L2_39/ypnkqyqrzsrkpiejyicl.jpg'

# %% [markdown]
# ### 4.2 RGB색상
# #### 이미지 데이터의 RGB값 이해

# %%
import matplotlib.pyplot as plt
img = plt.imread(f'{img_path}/L2_39/ypnkqyqrzsrkpiejyicl.jpg')
print(img.shape)
img
# Out:
# (3508, 2480, 3)
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
# ...

# %%
plt.imshow(img)
plt.axis("off")
# Out:
# (-0.5, 2479.5, 3507.5, -0.5)

# %%
img[:,:,0] #R
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
img[:,:,1] #G
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
img[:,:,2] #B
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %% [markdown]
# ### 4.3 이미지 처리 도구

# %%
img_hamburger = f'{img_path}/L2_39/ypnkqyqrzsrkpiejyicl.jpg'
img_hamburger
# Out:
# '/content/drive/MyDrive/2022 DataCreatorCamp_나 is NICE/대학부 데이터셋/L2_39/ypnkqyqrzsrkpiejyicl.jpg'

# %% [markdown]
# #### 4.3.1 PIL(Pillow)

# %%
from PIL import Image, ImageFilter
original = Image.open(img_hamburger)
original
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2480x3508 at 0x7FE25CFCDDD0>

# %%
# 이미지 사이즈 확인
img_size = original.size 
img_size
# Out:
# (2480, 3508)

# %%
# 이미지 사이즈 변경
original = original.resize((150,150))
original
# Out:
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7FE25CF68850>

# %%
# 이미지 저장
original.save('original.png')

# %%
# 흐리게 만들기
original.filter(ImageFilter.BLUR)
# Out:
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7FE25CF73710>

# %%
# 행렬의 등고선 추출
original.filter(ImageFilter.CONTOUR)
# Out:
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7FE25CF16050>

# %%
# EMBOSS 효과
original.filter(ImageFilter.EMBOSS)
# Out:
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7FE25D185DD0>

# %% [markdown]
# ### 4.3.2 OpenCV

# %%
img_paths_jpg = img_files_jpg[1]
img_paths_jpg
# Out:
# '/content/drive/MyDrive/2022 DataCreatorCamp_나 is NICE/대학부 데이터셋/L2_39/twafludgafarnkwpmjuf.jpg'

# %%
import cv2

img = cv2.imread(img_paths_jpg, cv2.IMREAD_COLOR)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img.shape
# Out:
# (300, 300, 3)

# %%
img
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
from matplotlib import pyplot as plt

plt.imshow(img)
plt.axis("off")
# Out:
# (-0.5, 299.5, 299.5, -0.5)

# %%
img_150 = cv2.resize(img, (150,150))
plt.imshow(img_150, cmap="gray")
plt.show()

# %%
# 흑백 이미지로 변화
image = cv2.imread(img_paths_jpg, cv2.IMREAD_GRAYSCALE)
plt.imshow(image, cmap="gray")
plt.axis("off")
plt.show()

# %%
# 이미지 흐리게
image_blurry = cv2.blur(image, (50,50))
plt.imshow(image_blurry, cmap="gray")
plt.axis("off")
plt.show()

# %%
# 적용적 임계처리: 어떤 값보다 큰 값을 가진 픽셀을 흰색으로 만들고 작은 값을 가진 픽셀은 검은색으로 만드는 과정
max_output_value = 255
neighborhood_size = 99
subtract_from_mean = 10
image_binarized = cv2.adaptiveThreshold(image, max_output_value,
                                        cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY,
                                        neighborhood_size, subtract_from_mean)
plt.imshow(image_binarized, cmap="gray")
plt.axis("off")
plt.show()
